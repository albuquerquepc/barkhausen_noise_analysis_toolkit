# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import numpy as np
from s0_constants_and_pathing import SAMPLING_RATE

x_axis = np.loadtxt("Mean_Py_1000nm_R798D_0.05Hz_100kHz_4MSs/R798D_t.dat")


y_axis = np.loadtxt("//home/paulo/Scripts/barkhausen-noise-analysis/Mean_Py_1000nm_R798D_0.05Hz_100kHz_4MSs/R798D_mean.dat")

#ax = plt.gca()

#ax.xaxis.set_major_locator(MaxNLocator(nbins=5)) # Aim for 5 ticks

plt.plot(x_axis, y_axis, "-")
plt.show()
