# %%
import matplotlib.pyplot as plt
import numpy as np

path_freq: str = "/home/paulo/Documentos/ic_gmag/medidas/Py(1000nm)/Barkhausen/Prepared_Py_1000nm_R798D_0.05Hz_100kHz_4MSs/R798D_t.dat"
spectrum: str = "/home/paulo/Documentos/ic_gmag/medidas/Py(1000nm)/Barkhausen/Prepared_Py_1000nm_R798D_0.05Hz_100kHz_4MSs/R798D001.dat"

x = np.loadtxt(path_freq)
y = np.loadtxt(spectrum)

plt.plot(x, y, linestyle="none", marker='o', ms=1, color="black")
plt.xlabel("Frequência (Hz)")
plt.ylabel("S(f) (arb. unit)")

#plt.savefig(f"/home/paulo/Área de trabalho/", dpi=600)
plt.show()
